# %%
import pandas as pd

# %% [markdown]
# Data source:
# https://www.kaggle.com/datasets/vipulshinde/incident-response-log?resource=download

# %%
df = pd.read_csv('/Users/gracefujinaga/Documents/Northwestern/MSDS_460/monte-carlo-methods/Data/incident_event_log.csv')

# %%
len(df)
# Out:
# 119998

# %%
df
# Out:
#             number incident_state  active  reassignment_count  reopen_count  \
# 0       INC0000045            New    True                   0             0
# 1       INC0000045       Resolved    True                   0             0
# 2       INC0000045       Resolved    True                   0             0
# 3       INC0000045         Closed   False                   0             0
# 4       INC0000047            New    True                   0             0
# ...            ...            ...     ...                 ...           ...
# 119993  INC0029231       Resolved    True                   0             0
# 119994  INC0029231         Closed   False                   0             0
# 119995  INC0029232       Resolved    True                   0             0
# 119996  INC0029232         Closed   False                   0             0
# 119997  INC0029233            New    True                   0             0
#
# ...

# %%
# Print information about the DataFrame
print(len(df))
print(df.dtypes)
print(df.columns)

df = df[['number', 'incident_state', 'active', 'reassignment_count', 'sys_mod_count', 'caller_id']]
# Out:
# 119998
# number                     object
# incident_state             object
# active                       bool
# reassignment_count          int64
# reopen_count                int64
# sys_mod_count               int64
# made_sla                     bool
# caller_id                  object
# opened_by                  object
# opened_at                  object
# sys_created_by             object
# sys_created_at             object
# sys_updated_by             object
# sys_updated_at             object
# contact_type               object
# location                   object
# category                   object
# subcategory                object
# u_symptom                  object
# cmdb_ci                    object
# impact                     object
# urgency                    object
# priority                   object
# assignment_group           object
# assigned_to                object
# knowledge                    bool
# u_priority_confirmation      bool
# ...

# %%
df.to_csv('/Users/gracefujinaga/Documents/Northwestern/MSDS_460/monte-carlo-methods/Data/cleaned_log_data.csv', index=False)

# %% [markdown]
# ## Set up the Postgresql database
#
# psql -U postgres -f /Users/gracefujinaga/Documents/Northwestern/MSDS_460/monte-carlo-methods/create_database.sql
#
# psql -U username -d database_name -h host -p port
# psql -U postgres -d monte_carlo_db

# %% [markdown]
# ## Set up mongo
#
# mongoimport --db monte_carlo_db --collection logs --type csv --file /Users/gracefujinaga/Documents/Northwestern/MSDS_460/monte-carlo-methods/Data/cleaned_log_data.csv --headerline
